# %% [markdown]
# ![download.png](attachment:431a9945-22f7-48c6-ba7f-e9fe9509615d.png)

# %% [markdown]
# # Introduction To **Pandas**.
# * Pandas is an open source library built on top of **NumPy**.
# * It allows for fast analysis and data cleaning and prepartion.
# * It excels in performance and Productivity
# * It also has built-in Visualization features.
# * It can work with data from a wide variety of sources.
# * You'll need to install Pandas by going to your command line or terminal and using either
#       - conda install pandas
#       - pip   install pandas

# %% [markdown]
# ### Topics to be Covered:
# * 1. Series
# * 2. DataFrames
# * 3. Missing Data
# * 4. GroupBy
# * 5. Merging,Joining, and concatenating
# * 6. Operations
# * 7. Data Input and Output

# %% [markdown]
# ## 1. Series
# * A Series is very similar to the NumPy Arrays as it is built on the NumPy Array object.
#     - But what differentiates NumPy arrays with the Pandas Series
# * Series has Axis Labels means Indexed by Labels.
# * Let's view this

# %% [markdown]
# ![images.png](attachment:f282cbb5-377d-488d-a762-58339d2d4c82.png)

# %%
# Importing the Modules:
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# * Lets create various serious from various object types

# %%
labels = ["a","b","c"] # List data type
my_data = [10,20,30] # Numerical List data type
arr = np.array(my_data) # array type Numpy Data
d = {"aa":10 , "bb":20 , "cc":30} # Dictionary data type

# %%
# Now we have various data type's here
labels,type(labels)
# Out:
# (['a', 'b', 'c'], list)

# %%
my_data,type(my_data)
# Out:
# ([10, 20, 30], list)

# %%
arr , type(arr)
# Out:
# (array([10, 20, 30]), numpy.ndarray)

# %%
d,type(d)
# Out:
# ({'aa': 10, 'bb': 20, 'cc': 30}, dict)

# %%
# pd.series you can shift+tab to view that pandas series support various types of data type i have given you a quick view of it

# %% [markdown]
# ![22.07.2023_21.19.26_REC.png](attachment:655f5b33-7ffc-4605-a9ba-ad83247b2ba5.png)

# %%
# Let's Pass the data:
pd.Series(data = my_data) #Remember Guy's S in Series is Capital Always
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %% [markdown]
# * As it look Similat to NumPy Array but here you can see 0,1,2 Are Indexes

# %% [markdown]
# #### Here you can change the index's also

# %%
pd.Series(data = my_data , index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# * We can call this data Points using this index

# %%
# we can also do this in different way:
pd.Series(my_data,labels) # we dont have to call data and index
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# #### Let's see other ways to do make an array:

# %%
# We can also pass the Numpy array in the Series
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int32

# %%
# We can also pass the index here
pd.Series(arr,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int32

# %% [markdown]
# * Now let's pass the Dictionary ,
# * In dictionary , we get the keys as the Index:

# %%
pd.Series(d)
# Out:
# aa    10
# bb    20
# cc    30
# dtype: int64

# %% [markdown]
# ## Important Point:
# * What makes Pandas Series different from NumPy Array is **Pandas Series holds a variety of Object types**
# * Pandas Series holds almost hold every Data types

# %%
pd.Series(data=labels) # It also holds String type
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series(data = [sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %% [markdown]
# * **It also holds Built-in Function**.
# * You can never do this in NumPy Array.
# * This means How flexible is Pandas Series as far as holding different object types.

# %% [markdown]
# #### Series:
#
# * **The key to using a series is understanding it's index in Pandas makes use of these index Names or Numbers by allowing for very fast lookup's and it works just like a hash table o a dictionary.**
#
# lets see some example how to grab information from Series

# %%
# Let's make two Series

ser1 = pd.Series([1,2,3,4],["India","USA","Russia","Ukraine"])
ser1
# Out:
# India      1
# USA        2
# Russia     3
# Ukraine    4
# dtype: int64

# %% [markdown]
# Country names are index and Numerical are datapoints.
#
# dtype = int64 that means all our data points are integers.

# %%
ser2 = pd.Series([1,2,5,4],["India","USA","PAK","Ukraine"])
ser2
# Out:
# India      1
# USA        2
# PAK        5
# Ukraine    4
# dtype: int64

# %%
#Let's grab some datapoints:
# It is same as grabbing object from Python Dictionary.

ser1["USA"] # we are using a string type as our index are string
# Out:
# 2

# %%
ser3 = pd.Series(data=labels)
ser3
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %% [markdown]
# Here data points as strings as dtype = object but index are integer we can use things like this now:

# %%
ser3[1]
# Out:
# 'b'

# %%
ser1
# Out:
# India      1
# USA        2
# Russia     3
# Ukraine    4
# dtype: int64

# %%
ser2
# Out:
# India      1
# USA        2
# PAK        5
# Ukraine    4
# dtype: int64

# %%
ser1 + ser2
# Out:
# India      2.0
# PAK        NaN
# Russia     NaN
# USA        4.0
# Ukraine    8.0
# dtype: float64

# %% [markdown]
# **Important point:**
# * As India is on both the series it added up both the data points.
# * but PAK is just once so used NaN
# * as well as for Russia

# %% [markdown]
# #### When ever we add , sub , multiply or divide the Series operation.
#
# #### We get up D-type as **Float64** , So that we will Not Lose any of the information.

# %% [markdown]
# * This is up for the Pandas.Series
# * Next Pandas.DataFrame

# %% [markdown]
# #### Keep Learning Keep Growing
# #### Raj Kulhade
